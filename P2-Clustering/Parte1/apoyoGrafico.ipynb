# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing as pp
from sklearn.model_selection import train_test_split

# %%
mamografias= pd.read_csv("./mamografias.csv",na_values=["?"])
mamografias=mamografias.dropna() 

le = pp.LabelEncoder()
columna_codificada=le.fit_transform(mamografias['Shape'])
mamografias['Shape']=le.fit_transform(mamografias['Shape'])
mamografias['Severity']=le.fit_transform(mamografias['Severity'])
atributos=mamografias[['BI-RADS','Age','Shape','Margin','Density']]
target=mamografias['Severity']
data_train, data_test, target_train, target_test = train_test_split(atributos ,target, test_size = 0.8, random_state = 5)

sns.set(style="whitegrid", color_codes=True)
sns.set(rc={'figure.figsize':(28,8.27)})
sns.countplot('Age',data=mamografias,hue = 'Severity')
plt.savefig('./edadSeveidad'+'.png')

# %%
sns.set(style="whitegrid", color_codes=True)
sns.set(rc={'figure.figsize':(15,5)})
sns.countplot('Density',data=mamografias,hue = 'Severity')
plt.savefig('./densidad'+'.png')

# %%
sns.set(style="whitegrid", color_codes=True)
sns.set(rc={'figure.figsize':(15,5)})
sns.countplot('Shape',data=mamografias,hue = 'Severity')
plt.savefig('./shape'+'.png')

# %%
sns.boxplot(x='Density', y="Shape", data=mamografias, hue="Severity")
#plt.show()
plt.savefig('./densidadmasShape'+'.png')

# %%
sns.boxplot(data=mamografias, x="Shape", y="Severity")
